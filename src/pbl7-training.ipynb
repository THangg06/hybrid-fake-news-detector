# %% [markdown]
# # TF-IDF + XGBoost Pipeline (Single Config)
# Simple pipeline for fake news detection with default hyperparameters

# %%
# ============================================================================
# IMPORTS
# ============================================================================
from __future__ import annotations

import json
import re
import shutil
from pathlib import Path
from typing import Dict, List, Sequence, Tuple
from datetime import datetime

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.sparse import csr_matrix, hstack
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    confusion_matrix,
    f1_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
    classification_report,
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_sample_weight
from xgboost import XGBClassifier

import torch
from transformers import RobertaTokenizer, RobertaModel
from tqdm import tqdm

sns.set_theme(style="whitegrid")
print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %%
# ============================================================================
# CONSTANTS & SETUP
# ============================================================================
RANDOM_STATE = 42

from pathlib import Path

PROJECT_ROOT = Path.cwd()

DATA_PATH = Path("/kaggle/input/datasets/ltrungphong/dataset-123/data/full_data.csv")

RESULTS_DIR = PROJECT_ROOT / "results"
PLOTS_DIR = PROJECT_ROOT / "plots"
CM_DIR = PROJECT_ROOT / "confusion_matrix"
MODELS_DIR = PROJECT_ROOT / "models"

def ensure_output_dirs() -> None:
    for directory in [RESULTS_DIR, PLOTS_DIR, CM_DIR, MODELS_DIR]:
        directory.mkdir(parents=True, exist_ok=True)

ensure_output_dirs()
print(f"Project root: {PROJECT_ROOT}")
print(f"Output directories created ✅")
# Out:
# Project root: /kaggle/working
# Output directories created ✅

# %%
# ============================================================================
# DATA PREPROCESSING
# ============================================================================
def normalize_schema(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    rename_map = {}
    if "text" in df.columns and "content" not in df.columns:
        rename_map["text"] = "content"
    if "tweet_id" in df.columns and "id" not in df.columns:
        rename_map["tweet_id"] = "id"
    if rename_map:
        df = df.rename(columns=rename_map)
    if "content" not in df.columns:
        raise ValueError("Dataset must contain a text column named 'content' or 'text'.")
    if "label" not in df.columns:
        raise ValueError("Dataset must contain a 'label' column.")
    return df


def canonical_label(value: object) -> str:
    text = str(value).strip().lower()
    text = re.sub(r"[\s_\-]+", "", text)
    return text


def encode_labels(labels: pd.Series) -> pd.Series:
    if pd.api.types.is_numeric_dtype(labels):
        numeric = pd.to_numeric(labels, errors="coerce")
        valid = set(numeric.dropna().unique().tolist())
        if valid.issubset({0, 1}):
            return numeric.astype(int)

    mapping = {
        "nonrumor": 0,
        "truth": 0,
        "true": 0,
        "real": 0,
        "legit": 0,
        "legitimate": 0,
        "false": 1,
        "rumor": 1,
        "fake": 1,
        "unverified": 1,
    }
    encoded = labels.map(lambda x: mapping.get(canonical_label(x)))
    if encoded.isna().any():
        invalid = sorted({str(v) for v in labels[encoded.isna()].unique().tolist()})
        raise ValueError(
            f"Unsupported labels found. Expected values similar to true/non-rumor/false/unverified. "
            f"Invalid values: {invalid}"
        )
    return encoded.astype(int)


def clean_text(text: object) -> str:
    if pd.isna(text):
        return ""
    value = str(text).lower()
    value = re.sub(r"http\S+|www\S+|https\S+", " ", value)
    value = re.sub(r"@[A-Za-z0-9_]+", " ", value)
    value = re.sub(r"#[A-Za-z0-9_]+", " ", value)
    value = re.sub(r"[^a-z\s]", " ", value)
    value = re.sub(r"\s+", " ", value).strip()
    return value


def extract_engineered_features(texts: Sequence[object]) -> np.ndarray:
    rows: List[List[float]] = []
    for raw_text in texts:
        value = "" if pd.isna(raw_text) else str(raw_text)
        word_count = len(value.split())
        upper_alpha = sum(1 for ch in value if ch.isalpha() and ch.isupper())
        alpha_count = sum(1 for ch in value if ch.isalpha())
        uppercase_ratio = (upper_alpha / alpha_count) if alpha_count else 0.0
        rows.append(
            [
                float(len(value)),
                float(word_count),
                float(value.count("!")),
                float(value.count("?")),
                float(uppercase_ratio),
            ]
        )
    return np.asarray(rows, dtype=np.float32)

print("✅ Data preprocessing functions defined")
# Out:
# ✅ Data preprocessing functions defined

# %%
# ============================================================================
# ROBERTA SETUP
# ============================================================================
print("Setting up RoBERTa model...")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
roberta_model = RobertaModel.from_pretrained("roberta-base")
roberta_model.to(device)
roberta_model.eval()

print("✅ RoBERTa model loaded successfully!")


def get_roberta_embedding(text):
    """Get [CLS] token embedding from RoBERTa (better for classification)."""
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=128)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = roberta_model(**inputs)
    # Use [CLS] token (index 0) instead of mean pooling
    return outputs.last_hidden_state[:, 0, :].cpu().numpy().flatten()


def extract_embeddings(texts):
    """Extract embeddings for a list of texts."""
    return np.vstack([get_roberta_embedding(text) for text in tqdm(texts, desc="Extracting RoBERTa embeddings")])
# Out:
# Setting up RoBERTa model...
# Using device: cuda
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ RoBERTa model loaded successfully!

# %%
# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
class TextFeatureBuilder(BaseEstimator, TransformerMixin):
    def __init__(
        self,
        max_features: int = 768,
        min_df: int = 2,
        max_df: float = 0.9,
        ngram_range: Tuple[int, int] = (1, 2),
    ) -> None:
        self.max_features = max_features
        self.min_df = min_df
        self.max_df = max_df
        self.ngram_range = ngram_range
        self.vectorizer = TfidfVectorizer(
            max_features=max_features,
            min_df=min_df,
            max_df=max_df,
            ngram_range=ngram_range,
            stop_words="english",
        )

    def fit(self, X: Sequence[object], y: Sequence[int] | None = None):
        raw_texts = ["" if pd.isna(text) else str(text) for text in X]
        cleaned_texts = [clean_text(text) for text in raw_texts]
        self.vectorizer.fit(cleaned_texts)
        return self

    def transform(self, X: Sequence[object]):
        raw_texts = ["" if pd.isna(text) else str(text) for text in X]
        cleaned_texts = [clean_text(text) for text in raw_texts]
        tfidf_matrix = self.vectorizer.transform(cleaned_texts)
        engineered = csr_matrix(extract_engineered_features(raw_texts))
        return hstack([tfidf_matrix, engineered], format="csr")

    def get_feature_names_out(self) -> np.ndarray:
        tfidf_names = self.vectorizer.get_feature_names_out()
        return np.concatenate([tfidf_names, np.asarray(ENGINEERED_FEATURE_NAMES, dtype=object)])

print("✅ TextFeatureBuilder class defined")
# Out:
# ✅ TextFeatureBuilder class defined

# %%
# ============================================================================
# LOAD DATASET
# ============================================================================
print("\n" + "="*80)
print("LOADING DATA")
print("="*80)

if not DATA_PATH.exists():
    raise FileNotFoundError(f"Dataset not found: {DATA_PATH}")

df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df)} total records")

df = normalize_schema(df)
df = df[["content", "label"]].copy()
df["content"] = df["content"].fillna("").astype(str)
df["label"] = encode_labels(df["label"])

print(f"Label distribution:")
print(df["label"].value_counts().sort_index())
# Out:
# ================================================================================
# LOADING DATA
# ================================================================================
# Loaded 2139 total records
# Label distribution:
# label
# 0    1158
# 1     981
# Name: count, dtype: int64

# %%
# ============================================================================
# TRAIN-TEST SPLIT (DEFAULT CONFIG: 80/20)
# ============================================================================
print("\n" + "="*80)
print("TRAIN-TEST SPLIT (80/20)")
print("="*80)

X = df["content"]
y = df["label"].to_numpy(dtype=int)

test_size = 0.20  # 80/20 split (keep 80% for train)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, random_state=RANDOM_STATE, stratify=y
)

print(f"Train set size: {len(X_train)}")
print(f"Test set size: {len(X_test)}")
print(f"Train label distribution:\n{pd.Series(y_train).value_counts().sort_index()}")
print(f"Test label distribution:\n{pd.Series(y_test).value_counts().sort_index()}")
# Out:
# ================================================================================
# TRAIN-TEST SPLIT (80/20)
# ================================================================================
# Train set size: 1711
# Test set size: 428
# Train label distribution:
# 0    926
# 1    785
# Name: count, dtype: int64
# Test label distribution:
# 0    232
# 1    196
# Name: count, dtype: int64

# %%
# ============================================================================
# EXTRACT FEATURES (RoBERTa + ENGINEERED - TF-IDF will be extracted per fold)
# ============================================================================
print("\n" + "="*80)
print("FEATURE EXTRACTION (RoBERTa + Engineered)")
print("="*80)

# Extract RoBERTa embeddings (no hyperparameters, extract once in outer loop)
print("\n→ Extracting RoBERTa embeddings (TRAIN)...")
X_train_roberta = extract_embeddings(X_train.values)
print(f"  RoBERTa shape: {X_train_roberta.shape}")

print("→ Extracting RoBERTa embeddings (TEST)...")
X_test_roberta = extract_embeddings(X_test.values)
print(f"  RoBERTa shape: {X_test_roberta.shape}")

# Scale RoBERTa embeddings (fit on train only)
print("\n→ Scaling RoBERTa embeddings...")
# roberta_scaler = StandardScaler()
# roberta_scaler.fit(X_train_roberta)

from sklearn.preprocessing import normalize

X_train_roberta_scaled = normalize(X_train_roberta)
X_test_roberta_scaled = normalize(X_test_roberta)

# X_train_roberta_scaled = roberta_scaler.transform(X_train_roberta)
# X_test_roberta_scaled = roberta_scaler.transform(X_test_roberta)

# # Extract engineered features
# print("→ Extracting engineered features (TRAIN)...")
# X_train_engineered = extract_engineered_features(X_train)
# print(f"  Engineered shape: {X_train_engineered.shape}")

# print("→ Extracting engineered features (TEST)...")
# X_test_engineered = extract_engineered_features(X_test)
# print(f"  Engineered shape: {X_test_engineered.shape}")

print(f"\n✅ Pre-extracted features (RoBERTa + Engineered) ready for CV!")
# Out:
# ================================================================================
# FEATURE EXTRACTION (RoBERTa + Engineered)
# ================================================================================
#
# → Extracting RoBERTa embeddings (TRAIN)...
# Extracting RoBERTa embeddings: 100%|██████████| 1711/1711 [00:14<00:00, 118.77it/s]
#   RoBERTa shape: (1711, 768)
# → Extracting RoBERTa embeddings (TEST)...
# Extracting RoBERTa embeddings: 100%|██████████| 428/428 [00:03<00:00, 124.29it/s]
#   RoBERTa shape: (428, 768)
#
# → Scaling RoBERTa embeddings...
#
# ✅ Pre-extracted features (RoBERTa + Engineered) ready for CV!

# %%
# ============================================================================
# TRAIN XGBOOST (DEFAULT CONFIG)
# ============================================================================
print("\n" + "="*80)
print("TRAINING XGBOOST")
print("="*80)

# ============================================================================
# CROSS-VALIDATION WITH HYPERPARAMETER GRID SEARCH
# ============================================================================
print("\n" + "="*80)
print("CROSS-VALIDATION WITH HYPERPARAMETER GRID SEARCH (5-Fold CV)")
print("="*80)

from sklearn.model_selection import KFold
from itertools import product

# Define hyperparameter grids
tfidf_params_grid = {
    "max_features": [768, 1536, 2046],
    "min_df": [3, 4, 5, 6],
}

xgboost_params_grid = {
    "n_estimators": [300, 500],
    "learning_rate": [0.03, 0.07],
    "max_depth": [3, 5, 8],
}

# Generate all combinations
tfidf_combinations = list(product(*tfidf_params_grid.values()))
xgboost_combinations = list(product(*xgboost_params_grid.values()))
tfidf_keys = list(tfidf_params_grid.keys())
xgboost_keys = list(xgboost_params_grid.keys())

print(f"\nTF-IDF combinations: {len(tfidf_combinations)}")
print(f"XGBoost combinations: {len(xgboost_combinations)}")
print(f"Total combinations per fold: {len(tfidf_combinations) * len(xgboost_combinations)}")
print(f"Total combinations (5 folds): {5 * len(tfidf_combinations) * len(xgboost_combinations)}\n")

# Initialize KFold (5 folds)
kfold = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# Track results
cv_results = []
best_score = -np.inf
best_tfidf_params = None
best_xgboost_params = None
best_model = None

# Total combinations
total_combos = 5 * len(tfidf_combinations) * len(xgboost_combinations)
combo_counter = 0

# OUTER LOOP: K-Fold splits
fold_counter = 0
for train_idx, val_idx in kfold.split(X_train):
    fold_counter += 1
    print(f"\n{'='*80}")
    print(f"FOLD {fold_counter}/5")
    print(f"{'='*80}")
    
    # Get fold data
    X_train_fold_all = X_train.iloc[train_idx].values
    X_val_fold_all = X_train.iloc[val_idx].values
    y_train_fold = y_train[train_idx]
    y_val_fold = y_train[val_idx]
    
    # Extract RoBERTa embeddings ONCE per fold (no hyperparameters)
    print(f"\n→ Extracting RoBERTa embeddings for fold {fold_counter}...")
    X_train_roberta_fold = extract_embeddings(X_train_fold_all)
    X_val_roberta_fold = extract_embeddings(X_val_fold_all)
    print(f"  Train RoBERTa shape: {X_train_roberta_fold.shape}")
    print(f"  Val RoBERTa shape: {X_val_roberta_fold.shape}")
    
    # Scale RoBERTa for this fold
    # roberta_scaler_fold = StandardScaler()
    # roberta_scaler_fold.fit(X_train_roberta_fold)
    # X_train_roberta_scaled_fold = roberta_scaler_fold.transform(X_train_roberta_fold)
    # X_val_roberta_scaled_fold = roberta_scaler_fold.transform(X_val_roberta_fold)

    X_train_roberta_scaled_fold = normalize(X_train_roberta_fold)
    X_val_roberta_scaled_fold = normalize(X_val_roberta_fold)
    
    # Extract engineered features for this fold
    # print(f"→ Extracting engineered features for fold {fold_counter}...")
    # X_train_eng_fold = extract_engineered_features(X_train_fold_all)
    # X_val_eng_fold = extract_engineered_features(X_val_fold_all)
    # print(f"  Train engineered shape: {X_train_eng_fold.shape}")
    # print(f"  Val engineered shape: {X_val_eng_fold.shape}")
    
    # MIDDLE LOOP: TF-IDF hyperparameters
    for tfidf_combo in tfidf_combinations:
        tfidf_params = dict(zip(tfidf_keys, tfidf_combo))
        
        # INNER LOOP: XGBoost hyperparameters
        for xgb_combo in xgboost_combinations:
            combo_counter += 1
            xgboost_params = dict(zip(xgboost_keys, xgb_combo))
            
            # Progress display
            progress_str = f"[{combo_counter:4d}/{total_combos}] (Fold {fold_counter}/5)"
            param_str = f"TF-IDF: max_feat={tfidf_params['max_features']}, min_df={tfidf_params['min_df']} | XGB: n_est={xgboost_params['n_estimators']}, lr={xgboost_params['learning_rate']}, depth={xgboost_params['max_depth']}"
            print(f"\n{progress_str} {param_str}")
            
            # Extract TF-IDF with current hyperparameters for this fold
            fold_builder = TextFeatureBuilder(
                max_features=tfidf_params["max_features"],
                min_df=tfidf_params["min_df"],
                max_df=0.9,
                ngram_range=(1, 2),
            )
            fold_builder.fit(X_train_fold_all)
            
            X_train_tfidf_fold = fold_builder.transform(X_train_fold_all).toarray()
            X_val_tfidf_fold = fold_builder.transform(X_val_fold_all).toarray()

            X_train_tfidf_fold_norm = normalize(X_train_tfidf_fold)
            X_val_tfidf_fold_norm = normalize(X_val_tfidf_fold)
            
            # Combine features (TF-IDF + RoBERTa + Engineered)
            X_train_combined = np.hstack([X_train_tfidf_fold_norm, X_train_roberta_scaled_fold])
            X_val_combined = np.hstack([X_val_tfidf_fold_norm, X_val_roberta_scaled_fold])
            
            # Train XGBoost model
            cv_model = XGBClassifier(
                n_estimators=xgboost_params["n_estimators"],
                max_depth=xgboost_params["max_depth"],
                learning_rate=xgboost_params["learning_rate"],
                eval_metric="logloss",
                tree_method="hist",
                random_state=RANDOM_STATE,
                n_jobs=-1,
                importance_type="gain",
                device='cuda',
                max_bin=256,
            )
            cv_model.fit(X_train_combined, y_train_fold, verbose=False)
            
            # Evaluate on validation fold
            y_val_pred_proba = cv_model.predict_proba(X_val_combined)[:, 1]
            y_val_pred = (y_val_pred_proba >= 0.5).astype(int)
            
            fold_f1 = f1_score(y_val_fold, y_val_pred, zero_division=0)
            fold_acc = accuracy_score(y_val_fold, y_val_pred)
            
            print(f"   → F1: {fold_f1:.4f}, Accuracy: {fold_acc:.4f}")
            
            # Store result
            cv_results.append({
                "fold": fold_counter,
                "tfidf_params": tfidf_params,
                "xgboost_params": xgboost_params,
                "fold_f1": fold_f1,
                "fold_acc": fold_acc,
            })

# ============================================================================
# FIND BEST CONFIG BASED ON AVERAGE SCORE ACROSS 5 FOLDS
# ============================================================================
print("\n" + "="*80)
print("AGGREGATING CV RESULTS (Average across 5 folds)")
print("="*80)

# Group results by config
config_results = {}
for result in cv_results:
    tfidf_key = str(result["tfidf_params"])
    xgb_key = str(result["xgboost_params"])
    config_key = (tfidf_key, xgb_key)
    
    if config_key not in config_results:
        config_results[config_key] = {
            "tfidf_params": result["tfidf_params"],
            "xgboost_params": result["xgboost_params"],
            "fold_f1_scores": [],
            "fold_acc_scores": [],
        }
    
    config_results[config_key]["fold_f1_scores"].append(result["fold_f1"])
    config_results[config_key]["fold_acc_scores"].append(result["fold_acc"])

# Compute averages and find best
print(f"\nTotal unique configurations tested: {len(config_results)}\n")

best_configs = []
for config_key, results in config_results.items():
    avg_f1 = np.mean(results["fold_f1_scores"])
    avg_acc = np.mean(results["fold_acc_scores"])
    std_f1 = np.std(results["fold_f1_scores"])
    std_acc = np.std(results["fold_acc_scores"])
    
    best_configs.append({
        "tfidf_params": results["tfidf_params"],
        "xgboost_params": results["xgboost_params"],
        "avg_f1": avg_f1,
        "std_f1": std_f1,
        "avg_acc": avg_acc,
        "std_acc": std_acc,
        "fold_f1_scores": results["fold_f1_scores"],
        "fold_acc_scores": results["fold_acc_scores"],
    })

# Sort by average F1 score
best_configs.sort(key=lambda x: x["avg_f1"], reverse=True)

# Display top 5 best configurations
print("Top 5 Best Configurations (by average F1 across 5 folds):\n")
for rank, config in enumerate(best_configs[:5], 1):
    print(f"{rank}. TF-IDF: {config['tfidf_params']} | XGBoost: {config['xgboost_params']}")
    print(f"   Avg F1:  {config['avg_f1']:.4f} ± {config['std_f1']:.4f}")
    print(f"   Avg Acc: {config['avg_acc']:.4f} ± {config['std_acc']:.4f}")
    print(f"   Fold F1 scores: {[f'{s:.4f}' for s in config['fold_f1_scores']]}")
    print()

# Get best configuration
best_config = best_configs[0]
best_tfidf_params = best_config["tfidf_params"]
best_xgboost_params = best_config["xgboost_params"]
best_score = best_config["avg_f1"]

# Display best result
print("="*80)
print("BEST HYPERPARAMETERS (FROM 5-FOLD CV - Average)")
print("="*80)
print(f"\nBest Average F1 Score: {best_score:.4f} ± {best_config['std_f1']:.4f}")
print(f"Best Average Accuracy: {best_config['avg_acc']:.4f} ± {best_config['std_acc']:.4f}")
print(f"Best TF-IDF params: {best_tfidf_params}")
print(f"Best XGBoost params: {best_xgboost_params}")

# Retrain on full training set with best hyperparameters
print("\n→ Retraining on full training set with best hyperparameters...")

# Extract TF-IDF on full training set with best params
feature_builder = TextFeatureBuilder(
    max_features=best_tfidf_params["max_features"],
    min_df=best_tfidf_params["min_df"],
    max_df=0.9,
    ngram_range=(1, 2),
)
feature_builder.fit(X_train)
X_train_tfidf_final = feature_builder.transform(X_train).toarray()
X_test_tfidf_final = feature_builder.transform(X_test).toarray()

X_train_tfidf_final_norm = normalize(X_train_tfidf_final)
X_test_tfidf_final_norm = normalize(X_test_tfidf_final)

# Combine all features for final model
X_train_features_final = np.hstack([X_train_tfidf_final_norm, X_train_roberta_scaled])
X_test_features_final = np.hstack([X_test_tfidf_final_norm, X_test_roberta_scaled])

# Split for loss tracking
X_train_fit, X_val, y_train_fit, y_val = train_test_split(
    X_train_features_final, y_train, test_size=0.2, random_state=RANDOM_STATE, stratify=y_train
)

# Train final model with eval tracking
model = XGBClassifier(
    n_estimators=best_xgboost_params["n_estimators"],
    max_depth=best_xgboost_params["max_depth"],
    learning_rate=best_xgboost_params["learning_rate"],
    eval_metric=["logloss", "error"],
    tree_method="hist",
    random_state=RANDOM_STATE,
    n_jobs=-1,
    importance_type="gain",
    device='cuda',
    max_bin=256,
)

# Train with eval_set to track loss and accuracy
eval_set = [(X_train_fit, y_train_fit), (X_val, y_val)]
model.fit(
    X_train_fit, 
    y_train_fit,
    eval_set=eval_set,
    verbose=False
)

# Store loss and accuracy history for visualization
results = model.evals_result()
train_loss = results['validation_0']['logloss']
val_loss = results['validation_1']['logloss']
train_error = results['validation_0']['error']
val_error = results['validation_1']['error']

# Convert error to accuracy (accuracy = 1 - error)
train_accuracy = [1 - e for e in train_error]
val_accuracy = [1 - e for e in val_error]

# Retrain on full training set (without eval_set) for final model
print("→ Final retraining on full training set (no validation split)...")
model_final = XGBClassifier(
    n_estimators=best_xgboost_params["n_estimators"],
    max_depth=best_xgboost_params["max_depth"],
    learning_rate=best_xgboost_params["learning_rate"],
    eval_metric="logloss",
    tree_method="hist",
    random_state=RANDOM_STATE,
    n_jobs=-1,
    importance_type="gain",
    device='cuda',
    max_bin=256,
)
model_final.fit(X_train_features_final, y_train, verbose=False)
model = model_final

# Store vectorizer for later use
# tfidf_vec = feature_builder.vectorizer
# roberta_scaler_final = roberta_scaler

print("✅ Training complete!")
# Out:
# ================================================================================
# TRAINING XGBOOST
# ================================================================================
#
# ================================================================================
# CROSS-VALIDATION WITH HYPERPARAMETER GRID SEARCH (5-Fold CV)
# ================================================================================
#
# TF-IDF combinations: 12
# XGBoost combinations: 12
# Total combinations per fold: 144
# Total combinations (5 folds): 720
#
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# → Extracting RoBERTa embeddings for fold 1...
# Extracting RoBERTa embeddings: 100%|██████████| 1368/1368 [00:10<00:00, 124.87it/s]
# Extracting RoBERTa embeddings: 100%|██████████| 343/343 [00:02<00:00, 127.16it/s]
#   Train RoBERTa shape: (1368, 768)
#   Val RoBERTa shape: (343, 768)
#
# [   1/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:751: UserWarning: [14:08:30] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
#    → F1: 0.7677, Accuracy: 0.7901
#
# [   2/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7564, Accuracy: 0.7784
#
# [   3/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7591, Accuracy: 0.7872
#
# [   4/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7604, Accuracy: 0.7813
#
# [   5/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7668, Accuracy: 0.7872
#
# [   6/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7871, Accuracy: 0.8076
#
# [   7/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7595, Accuracy: 0.7784
#
# [   8/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7619, Accuracy: 0.7813
#
# [   9/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7818, Accuracy: 0.8047
#
# [  10/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  11/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7756, Accuracy: 0.7959
#
# [  12/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7781, Accuracy: 0.7988
#
# [  13/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7677, Accuracy: 0.7901
#
# [  14/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7564, Accuracy: 0.7784
#
# [  15/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7582, Accuracy: 0.7843
#
# [  16/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7604, Accuracy: 0.7813
#
# [  17/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7668, Accuracy: 0.7872
#
# [  18/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7871, Accuracy: 0.8076
#
# [  19/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7595, Accuracy: 0.7784
#
# [  20/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7619, Accuracy: 0.7813
#
# [  21/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7702, Accuracy: 0.7930
#
# [  22/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  23/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7756, Accuracy: 0.7959
#
# [  24/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7781, Accuracy: 0.7988
#
# [  25/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7752, Accuracy: 0.7988
#
# [  26/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7692, Accuracy: 0.7901
#
# [  27/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7525, Accuracy: 0.7813
#
# [  28/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7571, Accuracy: 0.7755
#
# [  29/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7760, Accuracy: 0.7930
#
# [  30/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7818, Accuracy: 0.8047
#
# [  31/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7785, Accuracy: 0.7959
#
# [  32/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  33/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7557, Accuracy: 0.7813
#
# [  34/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  35/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7712, Accuracy: 0.7872
#
# [  36/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7752, Accuracy: 0.7988
#
# [  37/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7653, Accuracy: 0.7872
#
# [  38/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7638, Accuracy: 0.7872
#
# [  39/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7662, Accuracy: 0.7901
#
# [  40/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  41/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7658, Accuracy: 0.7843
#
# [  42/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7885, Accuracy: 0.8076
#
# [  43/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7613, Accuracy: 0.7843
#
# [  44/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7653, Accuracy: 0.7872
#
# [  45/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7778, Accuracy: 0.8017
#
# [  46/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7643, Accuracy: 0.7843
#
# [  47/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7732, Accuracy: 0.7930
#
# [  48/720] (Fold 1/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7846, Accuracy: 0.8047
#
# [  49/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7871, Accuracy: 0.8076
#
# [  50/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7677, Accuracy: 0.7901
#
# [  51/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7697, Accuracy: 0.7959
#
# [  52/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7673, Accuracy: 0.7843
#
# [  53/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7632, Accuracy: 0.7901
#
# [  54/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7818, Accuracy: 0.8047
#
# [  55/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7668, Accuracy: 0.7872
#
# [  56/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7588, Accuracy: 0.7813
#
# [  57/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7789, Accuracy: 0.8047
#
# [  58/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7532, Accuracy: 0.7726
#
# [  59/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7687, Accuracy: 0.7930
#
# [  60/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7692, Accuracy: 0.7901
#
# [  61/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7597, Accuracy: 0.7843
#
# [  62/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7597, Accuracy: 0.7843
#
# [  63/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7566, Accuracy: 0.7843
#
# [  64/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7821, Accuracy: 0.8017
#
# [  65/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7619, Accuracy: 0.7813
#
# [  66/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7742, Accuracy: 0.7959
#
# [  67/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7692, Accuracy: 0.7901
#
# [  68/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7524, Accuracy: 0.7755
#
# [  69/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7653, Accuracy: 0.7872
#
# [  70/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7707, Accuracy: 0.7901
#
# [  71/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7571, Accuracy: 0.7755
#
# [  72/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7668, Accuracy: 0.7872
#
# [  73/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7752, Accuracy: 0.7988
#
# [  74/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7692, Accuracy: 0.7901
#
# [  75/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7525, Accuracy: 0.7813
#
# [  76/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7571, Accuracy: 0.7755
#
# [  77/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7760, Accuracy: 0.7930
#
# [  78/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7818, Accuracy: 0.8047
#
# [  79/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7785, Accuracy: 0.7959
#
# [  80/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  81/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7557, Accuracy: 0.7813
#
# [  82/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  83/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7712, Accuracy: 0.7872
#
# [  84/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7752, Accuracy: 0.7988
#
# [  85/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7653, Accuracy: 0.7872
#
# [  86/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7638, Accuracy: 0.7872
#
# [  87/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7662, Accuracy: 0.7901
#
# [  88/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [  89/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7658, Accuracy: 0.7843
#
# [  90/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7885, Accuracy: 0.8076
#
# [  91/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7613, Accuracy: 0.7843
#
# [  92/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7653, Accuracy: 0.7872
#
# [  93/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7778, Accuracy: 0.8017
#
# [  94/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7643, Accuracy: 0.7843
#
# [  95/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7732, Accuracy: 0.7930
#
# [  96/720] (Fold 1/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7846, Accuracy: 0.8047
#
# [  97/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7871, Accuracy: 0.8076
#
# [  98/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7677, Accuracy: 0.7901
#
# [  99/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7697, Accuracy: 0.7959
#
# [ 100/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7673, Accuracy: 0.7843
#
# [ 101/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7632, Accuracy: 0.7901
#
# [ 102/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7818, Accuracy: 0.8047
#
# [ 103/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7668, Accuracy: 0.7872
#
# [ 104/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7588, Accuracy: 0.7813
#
# [ 105/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7789, Accuracy: 0.8047
#
# [ 106/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7532, Accuracy: 0.7726
#
# [ 107/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7687, Accuracy: 0.7930
#
# [ 108/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7692, Accuracy: 0.7901
#
# [ 109/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7597, Accuracy: 0.7843
#
# [ 110/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7597, Accuracy: 0.7843
#
# [ 111/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7566, Accuracy: 0.7843
#
# [ 112/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7821, Accuracy: 0.8017
#
# [ 113/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7619, Accuracy: 0.7813
#
# [ 114/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7742, Accuracy: 0.7959
#
# [ 115/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7692, Accuracy: 0.7901
#
# [ 116/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7524, Accuracy: 0.7755
#
# [ 117/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7653, Accuracy: 0.7872
#
# [ 118/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7707, Accuracy: 0.7901
#
# [ 119/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7571, Accuracy: 0.7755
#
# [ 120/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7668, Accuracy: 0.7872
#
# [ 121/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7752, Accuracy: 0.7988
#
# [ 122/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7692, Accuracy: 0.7901
#
# [ 123/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7525, Accuracy: 0.7813
#
# [ 124/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7571, Accuracy: 0.7755
#
# [ 125/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7760, Accuracy: 0.7930
#
# [ 126/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7818, Accuracy: 0.8047
#
# [ 127/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7785, Accuracy: 0.7959
#
# [ 128/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7580, Accuracy: 0.7784
#
# [ 129/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7557, Accuracy: 0.7813
#
# [ 130/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [ 131/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7712, Accuracy: 0.7872
#
# [ 132/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7752, Accuracy: 0.7988
#
# [ 133/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7653, Accuracy: 0.7872
#
# [ 134/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7638, Accuracy: 0.7872
#
# [ 135/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7662, Accuracy: 0.7901
#
# [ 136/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7580, Accuracy: 0.7784
#
# [ 137/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7658, Accuracy: 0.7843
#
# [ 138/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7885, Accuracy: 0.8076
#
# [ 139/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7613, Accuracy: 0.7843
#
# [ 140/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7653, Accuracy: 0.7872
#
# [ 141/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7778, Accuracy: 0.8017
#
# [ 142/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7643, Accuracy: 0.7843
#
# [ 143/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7732, Accuracy: 0.7930
#
# [ 144/720] (Fold 1/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7846, Accuracy: 0.8047
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# → Extracting RoBERTa embeddings for fold 2...
# Extracting RoBERTa embeddings: 100%|██████████| 1369/1369 [00:10<00:00, 125.74it/s]
# Extracting RoBERTa embeddings: 100%|██████████| 342/342 [00:02<00:00, 128.25it/s]
#   Train RoBERTa shape: (1369, 768)
#   Val RoBERTa shape: (342, 768)
#
# [ 145/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 146/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7386, Accuracy: 0.7661
#
# [ 147/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7492, Accuracy: 0.7807
#
# [ 148/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 149/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7658, Accuracy: 0.7836
#
# [ 150/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7362, Accuracy: 0.7632
#
# [ 151/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7379, Accuracy: 0.7632
#
# [ 152/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7540, Accuracy: 0.7749
#
# [ 153/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7632, Accuracy: 0.7895
#
# [ 154/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7687, Accuracy: 0.7924
#
# [ 155/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7476, Accuracy: 0.7690
#
# [ 156/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 157/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7231, Accuracy: 0.7515
#
# [ 158/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7622, Accuracy: 0.7865
#
# [ 159/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7467, Accuracy: 0.7778
#
# [ 160/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7395, Accuracy: 0.7632
#
# [ 161/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 162/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7432, Accuracy: 0.7778
#
# [ 163/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 164/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 165/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7500, Accuracy: 0.7778
#
# [ 166/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 167/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 168/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7340, Accuracy: 0.7690
#
# [ 169/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7231, Accuracy: 0.7515
#
# [ 170/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7622, Accuracy: 0.7865
#
# [ 171/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7467, Accuracy: 0.7778
#
# [ 172/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7395, Accuracy: 0.7632
#
# [ 173/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 174/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7432, Accuracy: 0.7778
#
# [ 175/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 176/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 177/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7500, Accuracy: 0.7778
#
# [ 178/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 179/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 180/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7340, Accuracy: 0.7690
#
# [ 181/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7320, Accuracy: 0.7602
#
# [ 182/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7613, Accuracy: 0.7836
#
# [ 183/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 184/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7365, Accuracy: 0.7573
#
# [ 185/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7417, Accuracy: 0.7719
#
# [ 186/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7224, Accuracy: 0.7573
#
# [ 187/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7460, Accuracy: 0.7690
#
# [ 188/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 189/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7327, Accuracy: 0.7632
#
# [ 190/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7532, Accuracy: 0.7719
#
# [ 191/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7351, Accuracy: 0.7661
#
# [ 192/720] (Fold 2/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7243, Accuracy: 0.7573
#
# [ 193/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7412, Accuracy: 0.7632
#
# [ 194/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7434, Accuracy: 0.7719
#
# [ 195/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7195, Accuracy: 0.7515
#
# [ 196/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7508, Accuracy: 0.7749
#
# [ 197/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7451, Accuracy: 0.7719
#
# [ 198/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7351, Accuracy: 0.7661
#
# [ 199/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7484, Accuracy: 0.7719
#
# [ 200/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7607, Accuracy: 0.7865
#
# [ 201/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7327, Accuracy: 0.7632
#
# [ 202/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7653, Accuracy: 0.7865
#
# [ 203/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7548, Accuracy: 0.7778
#
# [ 204/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7368, Accuracy: 0.7661
#
# [ 205/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7379, Accuracy: 0.7632
#
# [ 206/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7550, Accuracy: 0.7836
#
# [ 207/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7500, Accuracy: 0.7778
#
# [ 208/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7540, Accuracy: 0.7749
#
# [ 209/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7362, Accuracy: 0.7632
#
# [ 210/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7566, Accuracy: 0.7836
#
# [ 211/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7362, Accuracy: 0.7632
#
# [ 212/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7622, Accuracy: 0.7865
#
# [ 213/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7443, Accuracy: 0.7690
#
# [ 214/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7500, Accuracy: 0.7719
#
# [ 215/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7386, Accuracy: 0.7661
#
# [ 216/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7682, Accuracy: 0.7953
#
# [ 217/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7231, Accuracy: 0.7515
#
# [ 218/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 219/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7340, Accuracy: 0.7690
#
# [ 220/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7395, Accuracy: 0.7632
#
# [ 221/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7634, Accuracy: 0.7807
#
# [ 222/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7285, Accuracy: 0.7602
#
# [ 223/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 224/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7516, Accuracy: 0.7778
#
# [ 225/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7248, Accuracy: 0.7602
#
# [ 226/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 227/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7556, Accuracy: 0.7749
#
# [ 228/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7368, Accuracy: 0.7661
#
# [ 229/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7320, Accuracy: 0.7602
#
# [ 230/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7613, Accuracy: 0.7836
#
# [ 231/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 232/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7365, Accuracy: 0.7573
#
# [ 233/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7417, Accuracy: 0.7719
#
# [ 234/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7224, Accuracy: 0.7573
#
# [ 235/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7460, Accuracy: 0.7690
#
# [ 236/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 237/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7327, Accuracy: 0.7632
#
# [ 238/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7532, Accuracy: 0.7719
#
# [ 239/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7351, Accuracy: 0.7661
#
# [ 240/720] (Fold 2/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7243, Accuracy: 0.7573
#
# [ 241/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7412, Accuracy: 0.7632
#
# [ 242/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7434, Accuracy: 0.7719
#
# [ 243/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7195, Accuracy: 0.7515
#
# [ 244/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7508, Accuracy: 0.7749
#
# [ 245/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7451, Accuracy: 0.7719
#
# [ 246/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7351, Accuracy: 0.7661
#
# [ 247/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7484, Accuracy: 0.7719
#
# [ 248/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7607, Accuracy: 0.7865
#
# [ 249/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7327, Accuracy: 0.7632
#
# [ 250/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7653, Accuracy: 0.7865
#
# [ 251/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7548, Accuracy: 0.7778
#
# [ 252/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7368, Accuracy: 0.7661
#
# [ 253/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7379, Accuracy: 0.7632
#
# [ 254/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7550, Accuracy: 0.7836
#
# [ 255/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7500, Accuracy: 0.7778
#
# [ 256/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7540, Accuracy: 0.7749
#
# [ 257/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7362, Accuracy: 0.7632
#
# [ 258/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7566, Accuracy: 0.7836
#
# [ 259/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7362, Accuracy: 0.7632
#
# [ 260/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7622, Accuracy: 0.7865
#
# [ 261/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7443, Accuracy: 0.7690
#
# [ 262/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7500, Accuracy: 0.7719
#
# [ 263/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7386, Accuracy: 0.7661
#
# [ 264/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7682, Accuracy: 0.7953
#
# [ 265/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7231, Accuracy: 0.7515
#
# [ 266/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 267/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7340, Accuracy: 0.7690
#
# [ 268/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7395, Accuracy: 0.7632
#
# [ 269/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7634, Accuracy: 0.7807
#
# [ 270/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7285, Accuracy: 0.7602
#
# [ 271/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 272/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7516, Accuracy: 0.7778
#
# [ 273/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7248, Accuracy: 0.7602
#
# [ 274/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 275/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7556, Accuracy: 0.7749
#
# [ 276/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7368, Accuracy: 0.7661
#
# [ 277/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7320, Accuracy: 0.7602
#
# [ 278/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7613, Accuracy: 0.7836
#
# [ 279/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 280/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7365, Accuracy: 0.7573
#
# [ 281/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7417, Accuracy: 0.7719
#
# [ 282/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7224, Accuracy: 0.7573
#
# [ 283/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7460, Accuracy: 0.7690
#
# [ 284/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 285/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7327, Accuracy: 0.7632
#
# [ 286/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7532, Accuracy: 0.7719
#
# [ 287/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7351, Accuracy: 0.7661
#
# [ 288/720] (Fold 2/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7243, Accuracy: 0.7573
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# → Extracting RoBERTa embeddings for fold 3...
# Extracting RoBERTa embeddings: 100%|██████████| 1369/1369 [00:10<00:00, 126.54it/s]
# Extracting RoBERTa embeddings: 100%|██████████| 342/342 [00:02<00:00, 124.29it/s]
#   Train RoBERTa shape: (1369, 768)
#   Val RoBERTa shape: (342, 768)
#
# [ 289/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7267, Accuracy: 0.7515
#
# [ 290/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 291/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7368, Accuracy: 0.7661
#
# [ 292/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7412, Accuracy: 0.7632
#
# [ 293/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 294/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7500, Accuracy: 0.7719
#
# [ 295/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7284, Accuracy: 0.7515
#
# [ 296/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 297/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7386, Accuracy: 0.7661
#
# [ 298/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7556, Accuracy: 0.7749
#
# [ 299/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7604, Accuracy: 0.7807
#
# [ 300/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7668, Accuracy: 0.7865
#
# [ 301/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7226, Accuracy: 0.7485
#
# [ 302/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 303/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7368, Accuracy: 0.7661
#
# [ 304/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7256, Accuracy: 0.7456
#
# [ 305/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 306/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7500, Accuracy: 0.7719
#
# [ 307/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7220, Accuracy: 0.7456
#
# [ 308/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7532, Accuracy: 0.7778
#
# [ 309/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7386, Accuracy: 0.7661
#
# [ 310/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7484, Accuracy: 0.7661
#
# [ 311/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7604, Accuracy: 0.7807
#
# [ 312/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7668, Accuracy: 0.7865
#
# [ 313/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7284, Accuracy: 0.7515
#
# [ 314/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7348, Accuracy: 0.7573
#
# [ 315/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7261, Accuracy: 0.7573
#
# [ 316/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7389, Accuracy: 0.7602
#
# [ 317/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7372, Accuracy: 0.7602
#
# [ 318/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7500, Accuracy: 0.7778
#
# [ 319/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7460, Accuracy: 0.7690
#
# [ 320/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7325, Accuracy: 0.7544
#
# [ 321/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7403, Accuracy: 0.7661
#
# [ 322/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7348, Accuracy: 0.7573
#
# [ 323/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7452, Accuracy: 0.7661
#
# [ 324/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7451, Accuracy: 0.7719
#
# [ 325/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7412, Accuracy: 0.7632
#
# [ 326/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7348, Accuracy: 0.7573
#
# [ 327/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7613, Accuracy: 0.7836
#
# [ 328/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7539, Accuracy: 0.7690
#
# [ 329/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7443, Accuracy: 0.7690
#
# [ 330/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7468, Accuracy: 0.7661
#
# [ 331/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7412, Accuracy: 0.7632
#
# [ 332/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7389, Accuracy: 0.7602
#
# [ 333/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7573, Accuracy: 0.7807
#
# [ 334/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7453, Accuracy: 0.7602
#
# [ 335/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7548, Accuracy: 0.7778
#
# [ 336/720] (Fold 3/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7395, Accuracy: 0.7632
#
# [ 337/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7331, Accuracy: 0.7573
#
# [ 338/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7261, Accuracy: 0.7485
#
# [ 339/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7434, Accuracy: 0.7719
#
# [ 340/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7256, Accuracy: 0.7456
#
# [ 341/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7524, Accuracy: 0.7749
#
# [ 342/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7451, Accuracy: 0.7719
#
# [ 343/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7649, Accuracy: 0.7807
#
# [ 344/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7308, Accuracy: 0.7544
#
# [ 345/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7468, Accuracy: 0.7719
#
# [ 346/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7296, Accuracy: 0.7485
#
# [ 347/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7524, Accuracy: 0.7749
#
# [ 348/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7451, Accuracy: 0.7719
#
# [ 349/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7412, Accuracy: 0.7632
#
# [ 350/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7331, Accuracy: 0.7573
#
# [ 351/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7393, Accuracy: 0.7690
#
# [ 352/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7438, Accuracy: 0.7602
#
# [ 353/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7562, Accuracy: 0.7719
#
# [ 354/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 355/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7634, Accuracy: 0.7807
#
# [ 356/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7419, Accuracy: 0.7661
#
# [ 357/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7351, Accuracy: 0.7661
#
# [ 358/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7469, Accuracy: 0.7602
#
# [ 359/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7524, Accuracy: 0.7690
#
# [ 360/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7597, Accuracy: 0.7836
#
# [ 361/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7284, Accuracy: 0.7515
#
# [ 362/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7348, Accuracy: 0.7573
#
# [ 363/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7261, Accuracy: 0.7573
#
# [ 364/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7389, Accuracy: 0.7602
#
# [ 365/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7372, Accuracy: 0.7602
#
# [ 366/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7500, Accuracy: 0.7778
#
# [ 367/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7460, Accuracy: 0.7690
#
# [ 368/720] (Fold 3/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7325, Accuracy: 0.7544
#
# ...
#
# [ 609/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 610/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7703, Accuracy: 0.8099
#
# [ 611/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7544, Accuracy: 0.7982
#
# [ 612/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7305, Accuracy: 0.7778
#
# [ 613/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7491, Accuracy: 0.7982
#
# [ 614/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7606, Accuracy: 0.8012
#
# [ 615/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7517, Accuracy: 0.7895
#
# [ 616/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7596, Accuracy: 0.7982
#
# [ 617/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7394, Accuracy: 0.7836
#
# [ 618/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 619/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7418, Accuracy: 0.7924
#
# [ 620/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7616, Accuracy: 0.8041
#
# [ 621/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7474, Accuracy: 0.7865
#
# [ 622/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7535, Accuracy: 0.7953
#
# [ 623/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 624/720] (Fold 5/5) TF-IDF: max_feat=768, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7312, Accuracy: 0.7807
#
# [ 625/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7410, Accuracy: 0.7895
#
# [ 626/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7708, Accuracy: 0.8070
#
# [ 627/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7473, Accuracy: 0.7982
#
# [ 628/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7589, Accuracy: 0.8012
#
# [ 629/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7527, Accuracy: 0.7982
#
# [ 630/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7240, Accuracy: 0.7749
#
# [ 631/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7703, Accuracy: 0.8099
#
# [ 632/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7633, Accuracy: 0.8041
#
# [ 633/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7670, Accuracy: 0.8099
#
# [ 634/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7482, Accuracy: 0.7953
#
# [ 635/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7384, Accuracy: 0.7865
#
# [ 636/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7266, Accuracy: 0.7778
#
# [ 637/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7500, Accuracy: 0.7953
#
# [ 638/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7518, Accuracy: 0.7953
#
# [ 639/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7633, Accuracy: 0.8041
#
# [ 640/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7527, Accuracy: 0.7982
#
# [ 641/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7544, Accuracy: 0.7982
#
# [ 642/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7660, Accuracy: 0.8070
#
# [ 643/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7429, Accuracy: 0.7895
#
# [ 644/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7483, Accuracy: 0.7895
#
# [ 645/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 646/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7730, Accuracy: 0.8129
#
# [ 647/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7447, Accuracy: 0.7895
#
# [ 648/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7554, Accuracy: 0.8012
#
# [ 649/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7455, Accuracy: 0.7924
#
# [ 650/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7429, Accuracy: 0.7895
#
# [ 651/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7509, Accuracy: 0.7982
#
# [ 652/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7579, Accuracy: 0.7982
#
# [ 653/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 654/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7240, Accuracy: 0.7749
#
# [ 655/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7527, Accuracy: 0.7982
#
# [ 656/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 657/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 658/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7703, Accuracy: 0.8099
#
# [ 659/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7544, Accuracy: 0.7982
#
# [ 660/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7305, Accuracy: 0.7778
#
# [ 661/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7491, Accuracy: 0.7982
#
# [ 662/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7606, Accuracy: 0.8012
#
# [ 663/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7517, Accuracy: 0.7895
#
# [ 664/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7596, Accuracy: 0.7982
#
# [ 665/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7394, Accuracy: 0.7836
#
# [ 666/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 667/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7418, Accuracy: 0.7924
#
# [ 668/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7616, Accuracy: 0.8041
#
# [ 669/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7474, Accuracy: 0.7865
#
# [ 670/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7535, Accuracy: 0.7953
#
# [ 671/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 672/720] (Fold 5/5) TF-IDF: max_feat=1536, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7312, Accuracy: 0.7807
#
# [ 673/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7410, Accuracy: 0.7895
#
# [ 674/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7562, Accuracy: 0.7982
#
# [ 675/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7599, Accuracy: 0.8041
#
# [ 676/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7544, Accuracy: 0.7982
#
# [ 677/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7579, Accuracy: 0.7982
#
# [ 678/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7410, Accuracy: 0.7895
#
# [ 679/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7703, Accuracy: 0.8099
#
# [ 680/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7616, Accuracy: 0.8041
#
# [ 681/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7633, Accuracy: 0.8041
#
# [ 682/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7622, Accuracy: 0.8012
#
# [ 683/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7562, Accuracy: 0.7982
#
# [ 684/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=3 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7429, Accuracy: 0.7895
#
# [ 685/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7500, Accuracy: 0.7953
#
# [ 686/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7518, Accuracy: 0.7953
#
# [ 687/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7633, Accuracy: 0.8041
#
# [ 688/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7527, Accuracy: 0.7982
#
# [ 689/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7544, Accuracy: 0.7982
#
# [ 690/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7660, Accuracy: 0.8070
#
# [ 691/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7429, Accuracy: 0.7895
#
# [ 692/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7483, Accuracy: 0.7895
#
# [ 693/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 694/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7730, Accuracy: 0.8129
#
# [ 695/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7447, Accuracy: 0.7895
#
# [ 696/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=4 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7554, Accuracy: 0.8012
#
# [ 697/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7455, Accuracy: 0.7924
#
# [ 698/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7429, Accuracy: 0.7895
#
# [ 699/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7509, Accuracy: 0.7982
#
# [ 700/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7579, Accuracy: 0.7982
#
# [ 701/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 702/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7240, Accuracy: 0.7749
#
# [ 703/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7527, Accuracy: 0.7982
#
# [ 704/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 705/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 706/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7703, Accuracy: 0.8099
#
# [ 707/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7544, Accuracy: 0.7982
#
# [ 708/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=5 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7305, Accuracy: 0.7778
#
# [ 709/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=3
#    → F1: 0.7491, Accuracy: 0.7982
#
# [ 710/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=5
#    → F1: 0.7606, Accuracy: 0.8012
#
# [ 711/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.03, depth=8
#    → F1: 0.7517, Accuracy: 0.7895
#
# [ 712/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=3
#    → F1: 0.7596, Accuracy: 0.7982
#
# [ 713/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=5
#    → F1: 0.7394, Accuracy: 0.7836
#
# [ 714/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=300, lr=0.07, depth=8
#    → F1: 0.7473, Accuracy: 0.7924
#
# [ 715/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=3
#    → F1: 0.7418, Accuracy: 0.7924
#
# [ 716/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=5
#    → F1: 0.7616, Accuracy: 0.8041
#
# [ 717/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.03, depth=8
#    → F1: 0.7474, Accuracy: 0.7865
#
# [ 718/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=3
#    → F1: 0.7535, Accuracy: 0.7953
#
# [ 719/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=5
#    → F1: 0.7402, Accuracy: 0.7865
#
# [ 720/720] (Fold 5/5) TF-IDF: max_feat=2046, min_df=6 | XGB: n_est=500, lr=0.07, depth=8
#    → F1: 0.7312, Accuracy: 0.7807
#
# ================================================================================
# AGGREGATING CV RESULTS (Average across 5 folds)
# ================================================================================
#
# Total unique configurations tested: 144
#
# Top 5 Best Configurations (by average F1 across 5 folds):
#
# 1. TF-IDF: {'max_features': 768, 'min_df': 3} | XGBoost: {'n_estimators': 500, 'learning_rate': 0.07, 'max_depth': 5}
#    Avg F1:  0.7519 ± 0.0188
#    Avg Acc: 0.7791 ± 0.0190
#    Fold F1 scores: ['0.7756', '0.7476', '0.7604', '0.7190', '0.7571']
#
# 2. TF-IDF: {'max_features': 768, 'min_df': 4} | XGBoost: {'n_estimators': 500, 'learning_rate': 0.07, 'max_depth': 5}
#    Avg F1:  0.7508 ± 0.0192
#    Avg Acc: 0.7785 ± 0.0194
#    Fold F1 scores: ['0.7756', '0.7419', '0.7604', '0.7190', '0.7571']
#
# 3. TF-IDF: {'max_features': 768, 'min_df': 4} | XGBoost: {'n_estimators': 300, 'learning_rate': 0.07, 'max_depth': 8}
#    Avg F1:  0.7505 ± 0.0226
#    Avg Acc: 0.7808 ± 0.0222
#    Fold F1 scores: ['0.7871', '0.7432', '0.7500', '0.7166', '0.7554']
#
# 4. TF-IDF: {'max_features': 1536, 'min_df': 4} | XGBoost: {'n_estimators': 500, 'learning_rate': 0.07, 'max_depth': 3}
#    Avg F1:  0.7493 ± 0.0241
#    Avg Acc: 0.7744 ± 0.0259
#    Fold F1 scores: ['0.7707', '0.7500', '0.7469', '0.7059', '0.7730']
#
# 5. TF-IDF: {'max_features': 2046, 'min_df': 4} | XGBoost: {'n_estimators': 500, 'learning_rate': 0.07, 'max_depth': 3}
#    Avg F1:  0.7493 ± 0.0241
#    Avg Acc: 0.7744 ± 0.0259
#    Fold F1 scores: ['0.7707', '0.7500', '0.7469', '0.7059', '0.7730']
#
# ================================================================================
# BEST HYPERPARAMETERS (FROM 5-FOLD CV - Average)
# ================================================================================
#
# Best Average F1 Score: 0.7519 ± 0.0188
# Best Average Accuracy: 0.7791 ± 0.0190
# Best TF-IDF params: {'max_features': 768, 'min_df': 3}
# Best XGBoost params: {'n_estimators': 500, 'learning_rate': 0.07, 'max_depth': 5}
#
# → Retraining on full training set with best hyperparameters...
# → Final retraining on full training set (no validation split)...
# ✅ Training complete!

# %%
# ============================================================================
# EVALUATE ON TEST SET
# ============================================================================
print("\n" + "="*80)
print("EVALUATION")
print("="*80)

y_prob = model.predict_proba(X_test_features_final)[:, 1]
y_pred = (y_prob >= 0.5).astype(int)

# Compute metrics
test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred, zero_division=0)
test_recall = recall_score(y_test, y_pred, zero_division=0)
test_f1 = f1_score(y_test, y_pred, zero_division=0)
test_roc_auc = roc_auc_score(y_test, y_prob)

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm[0, 0], cm[0, 1], cm[1, 0], cm[1, 1]

print(f"\n📊 TEST SET METRICS:")
print(f"  Accuracy:  {test_accuracy:.4f}")
print(f"  Precision: {test_precision:.4f}")
print(f"  Recall:    {test_recall:.4f}")
print(f"  F1 Score:  {test_f1:.4f}")
print(f"  ROC-AUC:   {test_roc_auc:.4f}")

print(f"\n🎯 CONFUSION MATRIX:")
print(f"     Pred 0  Pred 1")
print(f"Act 0  {tn:5d}  {fp:5d}")
print(f"Act 1  {fn:5d}  {tp:5d}")

print(f"\n📋 CLASSIFICATION REPORT:")
print(classification_report(y_test, y_pred, target_names=["Truth", "Rumor"]))
# Out:
# ================================================================================
# EVALUATION
# ================================================================================
#
# 📊 TEST SET METRICS:
#   Accuracy:  0.8131
#   Precision: 0.8021
#   Recall:    0.7857
#   F1 Score:  0.7938
#   ROC-AUC:   0.8842
#
# 🎯 CONFUSION MATRIX:
#      Pred 0  Pred 1
# Act 0    194     38
# Act 1     42    154
#
# 📋 CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#        Truth       0.82      0.84      0.83       232
#        Rumor       0.80      0.79      0.79       196
#
#     accuracy                           0.81       428
#    macro avg       0.81      0.81      0.81       428
# weighted avg       0.81      0.81      0.81       428

# %%
# ============================================================================
# VISUALIZATIONS
# ============================================================================
print("\n" + "="*80)
print("GENERATING PLOTS")
print("="*80)

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    cbar=False,
    xticklabels=["Truth", "Rumor"],
    yticklabels=["Truth", "Rumor"],
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(CM_DIR / "confusion_matrix.png", dpi=200)
plt.close()
print(f"✅ Saved: confusion_matrix.png")

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, linewidth=2.5, label=f"ROC AUC = {test_roc_auc:.4f}")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray", linewidth=1.5, label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / "roc_curve.png", dpi=200)
plt.close()
print(f"✅ Saved: roc_curve.png")
# Out:
# ================================================================================
# GENERATING PLOTS
# ================================================================================
# ✅ Saved: confusion_matrix.png
# ✅ Saved: roc_curve.png

# %%
# Loss Curve
plt.figure(figsize=(10, 6))
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, linewidth=2, label="Train Loss (LogLoss)", marker='o', markersize=3, alpha=0.7)
plt.plot(epochs, val_loss, linewidth=2, label="Validation Loss (LogLoss)", marker='s', markersize=3, alpha=0.7)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(PLOTS_DIR / "loss_curve.png", dpi=200)
plt.close()
print(f"✅ Saved: loss_curve.png")
# Out:
# ✅ Saved: loss_curve.png

# %%
# ============================================================================
# FEATURE IMPORTANCE
# ============================================================================
print("\nExtracting feature importance...")

# Get feature names from TextFeatureBuilder
all_feature_names_from_builder = feature_builder.get_feature_names_out()

# Separate TF-IDF feature names and engineered feature names
n_tfidf_features = len(all_feature_names_from_builder) - len(ENGINEERED_FEATURE_NAMES)
tfidf_feature_names = all_feature_names_from_builder[:n_tfidf_features]
# engineered_feature_names = all_feature_names_from_builder[n_tfidf_features:]

# Generate RoBERTa feature names
roberta_feature_names = np.array([f"RoBERTa_dim_{i}" for i in range(X_train_roberta_scaled.shape[1])])

# Combine all feature names
all_feature_names = np.concatenate([
    tfidf_feature_names,
    roberta_feature_names
    # engineered_feature_names
])

importances = np.asarray(model.feature_importances_, dtype=float)

top_k = min(20, importances.size)
top_indices = np.argsort(importances)[::-1][:top_k]
top_features = all_feature_names[top_indices]
top_values = importances[top_indices]

# Plot Feature Importance
plt.figure(figsize=(10, 7))
sns.barplot(x=top_values, y=top_features, palette="viridis")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Top 20 Feature Importances (TF-IDF + RoBERTa + Engineered)")
plt.tight_layout()
plt.savefig(PLOTS_DIR / "feature_importance.png", dpi=200)
plt.close()
print(f"✅ Saved: feature_importance.png")

# Print top features
print(f"\nTop 20 Features by Importance:")
for rank, (feat, val) in enumerate(zip(top_features, top_values), 1):
    print(f"  {rank:2d}. {feat:40s} → {val:.6f}")
# Out:
# Extracting feature importance...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/3111579631.py in <cell line: 0>()
#       5
#       6 # Get feature names from TextFeatureBuilder
# ----> 7 all_feature_names_from_builder = feature_builder.get_feature_names_out()
#       8
#       9 # Separate TF-IDF feature names and engineered feature names
#
# /tmp/ipykernel_57/1419481596.py in get_feature_names_out(self)
#      37     def get_feature_names_out(self) -> np.ndarray:
#      38         tfidf_names = self.vectorizer.get_feature_names_out()
# ---> 39         return np.concatenate([tfidf_names, np.asarray(ENGINEERED_FEATURE_NAMES, dtype=object)])
#      40
#      41 print("✅ TextFeatureBuilder class defined")
#
# NameError: name 'ENGINEERED_FEATURE_NAMES' is not defined

# %%
# Accuracy Curve
plt.figure(figsize=(10, 6))
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, linewidth=2, label="Train Accuracy", marker='o', markersize=3, alpha=0.7)
plt.plot(epochs, val_accuracy, linewidth=2, label="Validation Accuracy", marker='s', markersize=3, alpha=0.7)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(alpha=0.3)
plt.ylim([0, 1])
plt.tight_layout()
plt.savefig(PLOTS_DIR / "accuracy_curve.png", dpi=200)
plt.close()
print(f"✅ Saved: accuracy_curve.png")
# Out:
# ✅ Saved: accuracy_curve.png

# %%
# ============================================================================
# SAVE RESULTS & MODELS
# ============================================================================
print("\n" + "="*80)
print("SAVING RESULTS")
print("="*80)

# Results JSON
results = {
    "timestamp": datetime.now().isoformat(),
    "cv_selection": "Average across 5 folds",
    "cv_best_tfidf_params": best_tfidf_params,
    "cv_best_xgboost_params": best_xgboost_params,
    "cv_metrics": {
        "best_avg_f1_score": float(best_config["avg_f1"]),
        "best_f1_std": float(best_config["std_f1"]),
        "best_avg_accuracy": float(best_config["avg_acc"]),
        "best_acc_std": float(best_config["std_acc"]),
        "fold_f1_scores": [float(s) for s in best_config["fold_f1_scores"]],
        "fold_acc_scores": [float(s) for s in best_config["fold_acc_scores"]],
    },
    "split_ratio": "80/20 with 5-Fold CV",
    "features": "TF-IDF + RoBERTa (768) + Engineered (5)",
    "train_samples": int(len(X_train)),
    "test_samples": int(len(X_test)),
    "test_metrics": {
        "accuracy": float(test_accuracy),
        "precision": float(test_precision),
        "recall": float(test_recall),
        "f1_score": float(test_f1),
        "roc_auc": float(test_roc_auc),
    },
    "confusion_matrix": {
        "true_negatives": int(tn),
        "false_positives": int(fp),
        "false_negatives": int(fn),
        "true_positives": int(tp),
    },
}

with open(RESULTS_DIR / "results.json", "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2)
print("✅ Saved: results.json")

# # Save model
# joblib.dump(model, MODELS_DIR / "xgboost_model.joblib")
# print("✅ Saved: xgboost_model.joblib")

# # Save TF-IDF vectorizer
# joblib.dump(tfidf_vec, MODELS_DIR / "tfidf_vectorizer.joblib")
# print("✅ Saved: tfidf_vectorizer.joblib")

# # Save scaler
# joblib.dump(roberta_scaler_final, MODELS_DIR / "roberta_scaler.joblib")
# print("✅ Saved: roberta_scaler.joblib")

# print("\n" + "="*80)
# print("✅ PIPELINE COMPLETE!")
# print("="*80)
# print(f"\nResults saved to: {RESULTS_DIR}")
# print(f"Plots saved to: {PLOTS_DIR}")
# print(f"Models saved to: {MODELS_DIR}")
# Out:
# ================================================================================
# SAVING RESULTS
# ================================================================================
# ✅ Saved: results.json

# %%
# ============================================================================
# SUMMARY
# ============================================================================
print("\n📋 FINAL SUMMARY")
print("="*80)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test F1 Score: {test_f1:.4f}")
print(f"ROC-AUC Score: {test_roc_auc:.4f}")
print("="*80)
# Out:
# 📋 FINAL SUMMARY
# ================================================================================
# Test Accuracy: 0.8131
# Test F1 Score: 0.7938
# ROC-AUC Score: 0.8842
# ================================================================================
